# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

# %%
BATCH_SIZE = 128
NUM_CLASSES = 10
NUM_EPOCHS = 2

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

y_train = keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = keras.utils.to_categorical(y_test, NUM_CLASSES)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential()
from keras.layers import Input
model.add(Input(shape=(28, 28, 1)))
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(NUM_CLASSES, activation='softmax'))

# %%
model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

print("CNN 모델 학습을 시작합니다...")

# model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS, verbose=1)
model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=10, verbose=1)
# Out:
# CNN 모델 학습을 시작합니다...
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9210 - loss: 0.2571
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9741 - loss: 0.0879
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9788 - loss: 0.0692
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9832 - loss: 0.0542
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9861 - loss: 0.0450
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9873 - loss: 0.0410
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9881 - loss: 0.0359
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9897 - loss: 0.0328
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9905 - loss: 0.0286
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9914 - loss: 0.0257

# %%
cnn_score = model.evaluate(x_test, y_test, verbose=0)
print('최종 테스트 정확도(Accuracy): %.2f%%' % (cnn_score[1] * 100))
# Out:
# 최종 테스트 정확도(Accuracy): 99.18%
